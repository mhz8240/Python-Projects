# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_olivetti_faces
from sklearn.decomposition import PCA

# %%
# Step 1: Load the Olivetti faces dataset
data = fetch_olivetti_faces()
images = data.images
n_samples, h, w = images.shape
# Step 2: Preprocess the data by centering it around the mean
X = images.reshape(n_samples, -1)
mean_face = np.mean(X, axis=0)
X_centered = X - mean_face

# Step 3: Perform PCA
n_components = 100  # Number of principal components to keep
pca = PCA(n_components=n_components)
X_pca = pca.fit_transform(X_centered)

# %%
images.shape
# Out:
# (400, 64, 64)

# %%
# Step 4: Reconstruct   face the images using a subset of principal components
X_reconstructed = pca.inverse_transform(X_pca).reshape(400, -1)## type your code


#end code
X_reconstructed.shape
# Out:
# (400, 4096)

# %%
# Step 5: Visualize the results
n_rows = 4
n_cols = 4
plt.figure(figsize=(10, 8))
for i in range(n_rows * n_cols):
    plt.subplot(n_rows, n_cols, i + 1)
    if i < n_samples:
        plt.imshow(np.hstack((X[i].reshape(h, w), X_reconstructed[i].reshape(h, w))),
                   cmap='gray')
        plt.title("Original vs Reconstructed")
    plt.axis("off")
plt.tight_layout()
plt.show()

# %%
Selected_Face=25
Xorg=X[Selected_Face, :].reshape((h, w))
X_Reconst=X_reconstructed[Selected_Face, :].reshape((h, w))
mse_100 = np.mean((X_Reconst - Xorg))**2

plt.subplot(2, 2, 2)
plt.imshow(X_Reconst, cmap='gray')
plt.subplot(2, 2, 1)
plt.imshow(Xorg, cmap='gray')
plt.title("Original vs Reconstructed")
plt.axis('off')
print("mse_100=",mse_100)
# Out:
# mse_100= 0.2992528763318347

# %%
# Step 3: Perform PCA
n_components = 10  # Number of principal components to keep
pca = PCA(n_components=n_components)
X_pca = pca.fit_transform(X_centered)
# Step 4: Reconstruct   face the images using a subset of principal components
X_reconstructed = pca.inverse_transform(X_pca).reshape(400, -1)  ## type your code


#end code

X_Reconst=X_reconstructed[Selected_Face, :].reshape((h, w))
mse_10 = np.mean((X_Reconst - Xorg))**2
print("mse_10=",mse_10)

plt.subplot(2, 2, 2)
plt.imshow(X_Reconst, cmap='gray')
plt.subplot(2, 2, 1)
plt.imshow(Xorg, cmap='gray')
plt.title("Original vs Reconstructed")
plt.axis('off')
# Out:
# mse_10= 0.2994770528453081
# (-0.5, 63.5, 63.5, -0.5)
